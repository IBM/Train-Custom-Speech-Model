# %%
import glob
#!pip install striprtf
from striprtf.striprtf import rtf_to_text

if __name__ == '__main__':
    rtf_files = glob.glob('Documents/*.rtf')
    for rtf_name in rtf_files:
        txt_name = rtf_name.replace('.rtf','.txt')
        txt_file = open(txt_name, "x")
        content_txt = rtf_to_text(open(rtf_name).read())
        txt_file.write(content_txt)
        txt_file.close()

# %%
glob.glob('Documents/*.rtf')
# Out:
# ['Documents/128.rtf',
#  'Documents/114.rtf',
#  'Documents/100.rtf',
#  'Documents/15.rtf',
#  'Documents/29.rtf',
#  'Documents/28.rtf',
#  'Documents/14.rtf',
#  'Documents/101.rtf',
#  'Documents/115.rtf',
#  'Documents/129.rtf',
#  'Documents/103.rtf',
#  'Documents/117.rtf',
#  'Documents/16.rtf',
#  'Documents/249.rtf',
#  'Documents/248.rtf',
#  'Documents/17.rtf',
#  'Documents/116.rtf',
#  'Documents/102.rtf',
#  'Documents/106.rtf',
#  'Documents/112.rtf',
#  'Documents/13.rtf',
#  'Documents/12.rtf',
#  'Documents/113.rtf',
#  'Documents/107.rtf',
#  'Documents/111.rtf',
#  'Documents/105.rtf',
#  'Documents/139.rtf',
#  'Documents/38.rtf',
#  'Documents/10.rtf',
#  'Documents/11.rtf',
#  'Documents/39.rtf',
#  'Documents/138.rtf',
#  'Documents/104.rtf',
#  'Documents/110.rtf',
#  'Documents/177.rtf',
#  'Documents/89.rtf',
#  'Documents/163.rtf',
#  'Documents/188.rtf',
#  'Documents/76.rtf',
#  'Documents/62.rtf',
#  'Documents/229.rtf',
#  'Documents/201.rtf',
# ...

# %%
if __name__ == '__main__':
    for file_rtf in files:
        file_txt = file_rtf.replace('.rtf','.txt')
        f = open(path+file_txt, "x")
        content_txt = rtf_to_text(open(path+file_rtf).read())
        f.write(content_txt)
        f.close()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-17-ac22475d6951> in <module>()
#       5
#       6 if __name__ == '__main__':
# ----> 7     for file_rtf in files:
#       8         file_txt = file_rtf.replace('.rtf','.txt')
#       9         f = open(path+file_txt, "x")
#
# NameError: name 'files' is not defined

# %%
path = './Documents'
filenames = np.array(os.lis
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-16-b8ba73321a6a> in <module>()
#       1 path = './Documents'
# ----> 2 filenames = np.array(os.listdir(path))
#
# NameError: name 'np' is not defined

# %%
filenames[filenames[-3:]=='rtf']
# Out:
# '128.rtf'
